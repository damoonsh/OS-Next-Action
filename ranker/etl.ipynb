# %%
import pandas as pd

df = pd.read_csv('./mock.csv')

# %%
df = df.sort_values(['user_id', 'timestamp']).reset_index(drop=True)
df['prev_action_1'] = df.groupby('user_id')['action'].shift(1)
df['prev_action_2'] = df.groupby('user_id')['action'].shift(2)
df['prev_action_3'] = df.groupby('user_id')['action'].shift(3)

# %%
df[df.user_id == 'user_2']
# Out:
#                                 session_id user_id             timestamp  \
# 716   9d04d499-5249-47df-b6c1-0d95ba895cc9  user_2  2025-03-04T16:46:02Z
# 717   9d04d499-5249-47df-b6c1-0d95ba895cc9  user_2  2025-03-04T16:49:58Z
# 718   9d04d499-5249-47df-b6c1-0d95ba895cc9  user_2  2025-03-04T16:52:27Z
# 719   9d04d499-5249-47df-b6c1-0d95ba895cc9  user_2  2025-03-04T16:56:14Z
# 720   9d04d499-5249-47df-b6c1-0d95ba895cc9  user_2  2025-03-04T16:58:38Z
# ...                                    ...     ...                   ...
# 1062  48a69812-e4fc-42e5-91a9-8f4c0bd0bf7b  user_2  2025-05-24T18:30:06Z
# 1063  48a69812-e4fc-42e5-91a9-8f4c0bd0bf7b  user_2  2025-05-24T18:34:01Z
# 1064  0fac1311-96fb-41a4-a211-b4c93b8b7828  user_2  2025-05-25T12:51:39Z
# 1065  0fac1311-96fb-41a4-a211-b4c93b8b7828  user_2  2025-05-25T12:52:21Z
# 1066  0fac1311-96fb-41a4-a211-b4c93b8b7828  user_2  2025-05-25T13:01:08Z
#
#                                       action  \
# 716                  GET /sprints/{sprintId}
# 717                PATCH /sprints/{sprintId}
# 718                 DELETE /boards/{boardId}
# 719                PATCH /tickets/{ticketId}
# 720        PUT /costs/{service_id}/{cost_id}
# ...                                      ...
# 1062        POST /sprints/{sprintId}/tickets
# 1063               PATCH /tickets/{ticketId}
# 1064                             GET /boards
# 1065  PUT /revenue/{service_id}/{revenue_id}
# 1066              DELETE /sprints/{sprintId}
#
#                                 parameters  \
# 716                                     []
# 717                  ['state', 'sprintId']
# 718                            ['boardId']
# 719     ['status', 'ticketId', 'assignee']
# 720                            ['cost_id']
# ...                                    ...
# 1062                                    []
# 1063  ['ticketId', 'priority', 'assignee']
# 1064                                    []
# 1065                        ['service_id']
# 1066                          ['sprintId']
#
#                                prev_action_1  \
# 716                                      NaN
# 717                  GET /sprints/{sprintId}
# 718                PATCH /sprints/{sprintId}
# 719                 DELETE /boards/{boardId}
# 720                PATCH /tickets/{ticketId}
# ...                                      ...
# 1062               PATCH /sprints/{sprintId}
# 1063        POST /sprints/{sprintId}/tickets
# 1064               PATCH /tickets/{ticketId}
# 1065                             GET /boards
# 1066  PUT /revenue/{service_id}/{revenue_id}
#
#                          prev_action_2                     prev_action_3
# 716                                NaN                               NaN
# 717                                NaN                               NaN
# 718            GET /sprints/{sprintId}                               NaN
# 719          PATCH /sprints/{sprintId}           GET /sprints/{sprintId}
# 720           DELETE /boards/{boardId}         PATCH /sprints/{sprintId}
# ...                                ...                               ...
# 1062        DELETE /sprints/{sprintId}         PATCH /tickets/{ticketId}
# 1063         PATCH /sprints/{sprintId}        DELETE /sprints/{sprintId}
# 1064  POST /sprints/{sprintId}/tickets         PATCH /sprints/{sprintId}
# 1065         PATCH /tickets/{ticketId}  POST /sprints/{sprintId}/tickets
# 1066                       GET /boards         PATCH /tickets/{ticketId}
#
# [351 rows x 8 columns]

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['day'] = df['timestamp'].dt.day
df['month'] = df['timestamp'].dt.month
df['week'] = df['timestamp'].dt.isocalendar().week
df['year'] = df['timestamp'].dt.year
df['seconds_passed'] = (df['timestamp'].dt.hour * 3600 +
df['timestamp'].dt.minute * 60 +
df['timestamp'].dt.second)

# %%
df['pa1_ss'] = df['session_id'] == df.groupby('user_id')['session_id'].shift(1)
df['pa2_ss'] = df['session_id'] == df.groupby('user_id')['session_id'].shift(2)
df['pa3_ss'] = df['session_id'] == df.groupby('user_id')['session_id'].shift(3)

# %%
df.to_csv('cleaned.csv', index=False)
