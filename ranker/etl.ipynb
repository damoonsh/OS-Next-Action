# %%
import pandas as pd

df = pd.read_csv('./mock.csv')

# %%
df = df.sort_values(['user_id', 'timestamp']).reset_index(drop=True)
df['prev_action_1'] = df.groupby('user_id')['action'].shift(1)
df['prev_action_2'] = df.groupby('user_id')['action'].shift(2)
df['prev_action_3'] = df.groupby('user_id')['action'].shift(3)

# %%
df[df.user_id == 'user_2']
# Out:
#                                session_id user_id             timestamp  \
# 638  9dcec4bc-2ea3-47e0-ad15-58c796abd212  user_2  2025-03-01T12:04:05Z
# 639  9dcec4bc-2ea3-47e0-ad15-58c796abd212  user_2  2025-03-01T12:10:27Z
# 640  9dcec4bc-2ea3-47e0-ad15-58c796abd212  user_2  2025-03-01T12:19:25Z
# 641  9dcec4bc-2ea3-47e0-ad15-58c796abd212  user_2  2025-03-01T12:22:20Z
# 642  9dcec4bc-2ea3-47e0-ad15-58c796abd212  user_2  2025-03-01T12:32:25Z
# ..                                    ...     ...                   ...
# 949  1d682671-7982-4768-8b51-f3047eee67d3  user_2  2025-05-26T16:20:00Z
# 950  1d682671-7982-4768-8b51-f3047eee67d3  user_2  2025-05-26T16:24:44Z
# 951  41ced385-aab0-4e29-83fc-06d35f9688c6  user_2  2025-05-28T13:31:33Z
# 952  41ced385-aab0-4e29-83fc-06d35f9688c6  user_2  2025-05-28T13:37:04Z
# 953  41ced385-aab0-4e29-83fc-06d35f9688c6  user_2  2025-05-28T13:39:57Z
#
#                                      action  \
# 638                   GET /boards/{boardId}
# 639       PUT /invoices/{invoice_id}/status
# 640               PATCH /tickets/{ticketId}
# 641    POST /tickets/{ticketId}/transitions
# 642  PUT /revenue/{service_id}/{revenue_id}
# ..                                      ...
# 949                            POST /events
# 950                            GET /sprints
# 951                             GET /events
# 952       PUT /invoices/{invoice_id}/status
# 953                   GET /events/{eventId}
#
#                              parameters                         prev_action_1  \
# 638                                  []                                   NaN
# 639            ['status', 'invoice_id']                 GET /boards/{boardId}
# 640  ['priority', 'assignee', 'status']     PUT /invoices/{invoice_id}/status
# 641                        ['ticketId']             PATCH /tickets/{ticketId}
# 642                                  []  POST /tickets/{ticketId}/transitions
# ..                                  ...                                   ...
# 949                                  []      POST /sprints/{sprintId}/tickets
# 950               ['board_id', 'state']                          POST /events
# 951                         ['to_date']                          GET /sprints
# 952                                  []                           GET /events
# 953                                  []     PUT /invoices/{invoice_id}/status
#
#                             prev_action_2  \
# 638                                   NaN
# 639                                   NaN
# 640                 GET /boards/{boardId}
# 641     PUT /invoices/{invoice_id}/status
# 642             PATCH /tickets/{ticketId}
# ..                                    ...
# 949  POST /tickets/{ticketId}/transitions
# 950      POST /sprints/{sprintId}/tickets
# 951                          POST /events
# 952                          GET /sprints
# 953                           GET /events
#
#                             prev_action_3
# 638                                   NaN
# 639                                   NaN
# 640                                   NaN
# 641                 GET /boards/{boardId}
# 642     PUT /invoices/{invoice_id}/status
# ..                                    ...
# 949                           GET /events
# 950  POST /tickets/{ticketId}/transitions
# 951      POST /sprints/{sprintId}/tickets
# 952                          POST /events
# 953                          GET /sprints
#
# [316 rows x 8 columns]

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['day'] = df['timestamp'].dt.day
df['month'] = df['timestamp'].dt.month
df['week'] = df['timestamp'].dt.isocalendar().week
df['year'] = df['timestamp'].dt.year
df['seconds_passed'] = (df['timestamp'].dt.hour * 3600 +
df['timestamp'].dt.minute * 60 +
df['timestamp'].dt.second)

# %%
df['pa1_ss'] = df['session_id'] == df.groupby('user_id')['session_id'].shift(1)
df['pa2_ss'] = df['session_id'] == df.groupby('user_id')['session_id'].shift(2)
df['pa3_ss'] = df['session_id'] == df.groupby('user_id')['session_id'].shift(3)

# %%
df.to_csv('cleaned.csv', index=False)
